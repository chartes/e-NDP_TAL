# %% [markdown]
# # Notebook : Benchmark de lemmatisation (latin) d'un corpus HTR (XML PAGE)
#
# - Author: Lucas Terriel <lucas.terriel@chartes.psl.eu>
# - Date: 10/01/2023
#
# ## Motivation
#
# (Fr) Ce notebook permet de réaliser un *benchmark* de plusieurs lemmatiseurs sur un corpus acquis par HTR (XML PAGE). Chaque *taggers* produit un corpus pré-lémmatisé qui peut être analysé et éventuellement repris dans un outil de correction manuel de la lemmatisation (comme [Pyrrha](https://github.com/hipster-philology/pyrrha)). Ces données reprises pourront servir alors pour entraîner un nouveau modèle de lemmatisation. Ce benchmark a été mis en place dans le cadre du projet e-NDP.
#
#
# (En) This notebook realize a benchmark of several lemmatizers on a corpus acquired by HTR (XML PAGE). Each taggers produces a pre-lemmatized corpus that can be analyzed and possibly included in a manual lemmatization correction tool (like [Pyrrha](https://github.com/hipster-philology/pyrrha)). These collected data can then be used to train a new lemmatization model. This benchmark was set up as part of the e-NDP project.
#
# ## Overall process schema
#
# ![schema_du_notebook](./docs/benchmark_lemmatization.jpg)
#
#
# ## File tree description
# ```
#  lemmatization-post-benchmark/
# |
# ├── treetagger/ (Do not remove, Specific dependencies for the treetagger, available when launching the notebook)
# │
# ├── out_lemmatized_corpus/ (Contains the lematized corpora classified according to the taggers'name, this directory is created during the notebook execution)
# │    ├── cltk/
# │    ├── nlp_pie_lasla/
# │    ├── omnia/
# │    ├── ...
# │
# ├── lib/ (Do not remove, Contains notebook-specific dependencies)
# |
# ├── data_in/ (Contains  input data for the notebook)
# │    ├── ground-truth-htr/ (Cf. Notebook part 1. for details)
# │    ├── ground-truth-layout_list/ (Cf. Notebook part 1. for details)
# │
# ├── data_filtered/ (Contains filtered input data according to the layout, this directory is created during the notebook execution)
# |
# ├── lemmatize_corpus_main.ipynb (This actual notebook)
# |
# ├── gt_filtered_struct_to_lemmatize.json (This file allows you to view the recovery of text blocks according to the layout that will be passed in the taggers, this file is created during the notebook execution)
# |
# |
# └── environment.yml
# ```
#
#
# ## Lemmatizers available
#
# - [CLTK](http://cltk.org/) (classical latin)
# - OMNIA via [treetaggerwrapper](https://treetaggerwrapper.readthedocs.io/en/latest/)
# - [Lasla model](https://github.com/chartes/deucalion-model-lasla) model via [nlp-pie-taggers](https://github.com/hipster-philology/nlp-pie-taggers)
# - [ud_pipe](https://lindat.mff.cuni.cz/services/udpipe/) (models ittb, perseus, proeil) via spaCy extension ([spacy_udpipe](https://github.com/TakeLab/spacy-udpipe))

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1. Download e-NDP HTR ressources
#
# Create a `data_in/` directory that contains:
#
# * HTR Ground truth from E-NDP_HTR (`./data_in/ground-truth-htr/`) with XML ALTO and images;
# * List of GT with layout (`./data_in/ground-truth-layout_list.txt`)
#
# > These data are available on https://github.com/chartes/e-NDP_HTR

# %%
# Local path to HTR data
gt_files_dir_path = "./data_in/ground-truth-htr/"
gt_files_segmented_path_list = "./data_in/ground-truth-layout_list.txt"

# %% [markdown]
# ### 2. Filter only layout GT, prepare and inspect data before lemmatization

# %%
from lib.data_preprocessor import endpDataLoader
        
        
data_loader = endpDataLoader(filtered_layout_gt_list_path=gt_files_segmented_path_list, 
               in_gt_path=gt_files_dir_path,
               out_gt_filtered_path="./data_filtered/", 
               copy_images=False)

# Inspect GT text blocks to lemmatize
# data.gt_structure_to_lemmatize
# Out:
# The directory: ./data_filtered/ already exists, this action recreate your directory [Y/n] Y
# New directory: ./data_filtered/ is re-created.
# ✔️ data filtered and available: ./data_filtered/ and ready to lemmatize.
# * Inspect your texts blocks to lemmatize in file: gt_filtered_struct_to_lemmatize.json

# %% [markdown]
# ### 3. Setup taggers (in the future you can skip this step)

# %%
from lib.utils import init_taggers

init_taggers(arch="osx")
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# WARNING:root:
# It seems like you downloaded `pie` instead of git-cloning it or installing it with pip.
# We won't be able to check compatibility between pretrained models and `pie` version.
# * Initialize Omnia tagger for arch: osx
# * Omnia taggger is ready ✔️
# * Initialize Lasla model for NLP Pie tagger
# [████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████]
# [████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████]
# [██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████]
# [██████████████████████████████████████████████████]
# [██████████████████████████████████████████████████]
# [██████████████████████████████████████████████████]
# [██████████████████████████████████████████████████]
# [██████████████████████████████████████████████████]
# [██████████████████████████████████████████████████]
# [██████████████████████████████████████████████████]
# [██████████████████████████████████████████████████]
# [██████████████████████████████████████████████████]
# * NLP-Pie Lasla tagger is ready ✔️
# * Initialize UDPipe tagger via SpaCy
# Already downloaded a model for the 'la-ittb' language
# Already downloaded a model for the 'la-proiel' language
# Already downloaded a model for the 'la-perseus' language
# * UDPipe tagger with models: ['la-ittb', 'la-proiel', 'la-perseus'] is ready ✔️
# * Other taggers: collatinus, CLTK are ready✔️

# %% [markdown]
# ### 3. Run all lemmatization benchmark

# %%
# %%time

from lib.nlp import LemmatizerBenchmarkEngine

# If you run this engine for the first time initialize parameter `setup_taggers` to True 
lemmatizer_engine = LemmatizerBenchmarkEngine(
    data=data_loader.gt_structure_to_lemmatize, 
    output_tagged_corpus_path="./out_lemmatized_corpus",
)

# 1a) run all lemmatizer engine for a benchmark (time: ~13min)
lemmatizer_engine.run_benchmark()

# 1b) or run lemmatizer individually ...
# lemmatizer_engine.omnia_process()
# lemmatizer_engine.ud_pipe_process()
# lemmatizer_engine.cltk_process()
# ...
# Out:
# WARNING:TreeTagger:Abbreviation file not found: latin-abbreviations
# WARNING:TreeTagger:Processing without abbreviations file.
# ‎𐤀 CLTK version '1.1.6'.
# Pipeline for language 'Latin' (ISO: 'lat'): `LatinNormalizeProcess`, `LatinStanzaProcess`.
# [INFO] *> Directory: ./out_lemmatized_corpus is already created.
# [INFO] *> Run all lemmatization benchmark...
# [INFO] *> Initialize cltk tagger...
# [INFO] *> Directory: ./out_lemmatized_corpus/cltk is already created.
# CLTK tagger in progress with doc: ./data_filtered/FRAN_0393_12690_L.xml: 100%|██████████| 363/363 [04:42<00:00,  1.29it/s]
# [INFO] *> Initialize omnia tagger...
# [INFO] *> Directory: ./out_lemmatized_corpus/omnia is already created.
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_07065_L.xml:   0%|          | 0/363 [00:00<?, ?it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_06748_L.xml:   0%|          | 1/363 [00:03<20:08,  3.34s/it]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_12171_L.xml:   0%|          | 1/363 [00:03<20:08,  3.34s/it]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/0006_Right.xml:   0%|          | 1/363 [00:03<20:08,  3.34s/it]       Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_03686_L.xml:   0%|          | 1/363 [00:03<20:08,  3.34s/it]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_08872_L.xml:   0%|          | 1/363 [00:03<20:08,  3.34s/it]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_07967_L.xml:   0%|          | 1/363 [00:03<20:08,  3.34s/it]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_05217_L.xml:   0%|          | 1/363 [00:03<20:08,  3.34s/it]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_03627_L.xml:   3%|▎         | 11/363 [00:03<01:20,  4.37it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_06535_L.xml:   3%|▎         | 11/363 [00:03<01:20,  4.37it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_05335_L.xml:   3%|▎         | 11/363 [00:03<01:20,  4.37it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_05370_L.xml:   3%|▎         | 11/363 [00:03<01:20,  4.37it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_14096_L.xml:   6%|▌         | 20/363 [00:03<00:37,  9.07it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_07965_L.xml:   6%|▌         | 20/363 [00:03<00:37,  9.07it/s]Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_05188_L.xml:   8%|▊         | 29/363 [00:03<00:22, 14.90it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_05231_L.xml:   8%|▊         | 29/363 [00:03<00:22, 14.90it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_05328_L.xml:  10%|█         | 38/363 [00:03<00:14, 21.83it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_07207_L.xml:  13%|█▎        | 46/363 [00:03<00:11, 28.46it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_06592_L.xml:  13%|█▎        | 46/363 [00:03<00:11, 28.46it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_07063_L.xml:  13%|█▎        | 46/363 [00:03<00:11, 28.46it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_03355_L.xml:  13%|█▎        | 46/363 [00:03<00:11, 28.46it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/0014_Right.xml:  13%|█▎        | 46/363 [00:04<00:11, 28.46it/s]       Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_03310_L.xml:  15%|█▍        | 54/363 [00:04<00:09, 33.50it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_02852_L.xml:  15%|█▍        | 54/363 [00:04<00:09, 33.50it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_00557_L.xml:  15%|█▍        | 54/363 [00:04<00:09, 33.50it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_05331_L.xml:  15%|█▍        | 54/363 [00:04<00:09, 33.50it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_01656_L.xml:  15%|█▍        | 54/363 [00:04<00:09, 33.50it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_07087_L.xml:  15%|█▍        | 54/363 [00:04<00:09, 33.50it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_12153_L.xml:  17%|█▋        | 63/363 [00:04<00:07, 42.36it/s]Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_08419_L.xml:  17%|█▋        | 63/363 [00:04<00:07, 42.36it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_00774_L.xml:  17%|█▋        | 63/363 [00:04<00:07, 42.36it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_11043_L.xml:  20%|██        | 73/363 [00:04<00:05, 52.12it/s]Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_01040_L.xml:  20%|██        | 73/363 [00:04<00:05, 52.12it/s]Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/0001_Left.xml:  20%|██        | 73/363 [00:04<00:05, 52.12it/s]        Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_12231_L.xml:  23%|██▎       | 82/363 [00:04<00:04, 58.93it/s]Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_05251_L.xml:  23%|██▎       | 82/363 [00:04<00:04, 58.93it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_00898_L.xml:  23%|██▎       | 82/363 [00:04<00:04, 58.93it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_05504_L.xml:  25%|██▌       | 92/363 [00:04<00:04, 67.65it/s]Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_12377_L.xml:  25%|██▌       | 92/363 [00:04<00:04, 67.65it/s]Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_09136_L.xml:  25%|██▌       | 92/363 [00:04<00:04, 67.65it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_03544_L.xml:  25%|██▌       | 92/363 [00:04<00:04, 67.65it/s]Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_12108_L.xml:  28%|██▊       | 101/363 [00:04<00:03, 71.03it/s]Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_07064_L.xml:  28%|██▊       | 101/363 [00:04<00:03, 71.03it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_06749_L.xml:  30%|███       | 110/363 [00:04<00:03, 74.63it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_06534_L.xml:  30%|███       | 110/363 [00:04<00:03, 74.63it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_03626_L.xml:  30%|███       | 110/363 [00:04<00:03, 74.63it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_12759_L.xml:  30%|███       | 110/363 [00:04<00:03, 74.63it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_06750_L.xml:  33%|███▎      | 119/363 [00:04<00:03, 73.59it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_07966_L.xml:  33%|███▎      | 119/363 [00:04<00:03, 73.59it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_05835_L.xml:  33%|███▎      | 119/363 [00:04<00:03, 73.59it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_05377_L.xml:  33%|███▎      | 119/363 [00:04<00:03, 73.59it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_01065_L.xml:  35%|███▌      | 128/363 [00:04<00:03, 74.90it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_08418_L.xml:  35%|███▌      | 128/363 [00:04<00:03, 74.90it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_06591_L.xml:  35%|███▌      | 128/363 [00:05<00:03, 74.90it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_06593_L.xml:  40%|████      | 147/363 [00:05<00:02, 75.81it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_04441_L.xml:  40%|████      | 147/363 [00:05<00:02, 75.81it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_14213_L.xml:  43%|████▎     | 155/363 [00:05<00:02, 72.26it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_03658_L.xml:  43%|████▎     | 155/363 [00:05<00:02, 72.26it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_07387_L.xml:  43%|████▎     | 155/363 [00:05<00:02, 72.26it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_05375_L.xml:  43%|████▎     | 155/363 [00:05<00:02, 72.26it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_08536_L.xml:  45%|████▍     | 163/363 [00:05<00:02, 74.05it/s]Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_08343_L.xml:  48%|████▊     | 174/363 [00:05<00:02, 82.91it/s]Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_03358_L.xml:  48%|████▊     | 174/363 [00:05<00:02, 82.91it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_04165_L.xml:  48%|████▊     | 174/363 [00:05<00:02, 82.91it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_08383_L.xml:  48%|████▊     | 174/363 [00:05<00:02, 82.91it/s]Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_05238_L.xml:  50%|█████     | 183/363 [00:05<00:02, 77.68it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_07855_L.xml:  50%|█████     | 183/363 [00:05<00:02, 77.68it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_03261_L.xml:  50%|█████     | 183/363 [00:05<00:02, 77.68it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/0004_Right.xml:  50%|█████     | 183/363 [00:05<00:02, 77.68it/s]       Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/0005_Main_frame.xml:  53%|█████▎    | 191/363 [00:05<00:02, 76.90it/s]  Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_06977_L.xml:  55%|█████▍    | 199/363 [00:05<00:02, 74.91it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_00876_L.xml:  55%|█████▍    | 199/363 [00:05<00:02, 74.91it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_05282_L.xml:  55%|█████▍    | 199/363 [00:05<00:02, 74.91it/s]Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_02959_L.xml:  55%|█████▍    | 199/363 [00:05<00:02, 74.91it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_08381_L.xml:  57%|█████▋    | 207/363 [00:05<00:02, 74.06it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_07088_L.xml:  57%|█████▋    | 207/363 [00:06<00:02, 74.06it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/0002_Main_frame.xml:  57%|█████▋    | 207/363 [00:06<00:02, 74.06it/s]  Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_08005_L.xml:  57%|█████▋    | 207/363 [00:06<00:02, 74.06it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_03859_L.xml:  59%|█████▉    | 215/363 [00:06<00:02, 70.68it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_06973_L.xml:  62%|██████▏   | 224/363 [00:06<00:01, 74.49it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_02960_L.xml:  62%|██████▏   | 224/363 [00:06<00:01, 74.49it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/0015_Left.xml:  64%|██████▍   | 232/363 [00:06<00:01, 68.19it/s]        Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_08471_L.xml:  64%|██████▍   | 232/363 [00:06<00:01, 68.19it/s]Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_03497_L.xml:  64%|██████▍   | 232/363 [00:06<00:01, 68.19it/s]Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_02631_L.xml:  64%|██████▍   | 232/363 [00:06<00:01, 68.19it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_08473_L.xml:  64%|██████▍   | 232/363 [00:06<00:01, 68.19it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_05284_L.xml:  64%|██████▍   | 232/363 [00:06<00:01, 68.19it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/0004_Main_frame.xml:  67%|██████▋   | 243/363 [00:06<00:01, 75.75it/s]  Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_06747_L.xml:  67%|██████▋   | 243/363 [00:06<00:01, 75.75it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_08003_L.xml:  67%|██████▋   | 243/363 [00:06<00:01, 75.75it/s]Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_04380_L.xml:  67%|██████▋   | 243/363 [00:06<00:01, 75.75it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_02903_L.xml:  69%|██████▉   | 251/363 [00:06<00:01, 72.46it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_03628_L.xml:  69%|██████▉   | 251/363 [00:06<00:01, 72.46it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_11459_L.xml:  69%|██████▉   | 251/363 [00:06<00:01, 72.46it/s]Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_08756_L.xml:  71%|███████▏  | 259/363 [00:06<00:01, 70.91it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_07968_L.xml:  71%|███████▏  | 259/363 [00:06<00:01, 70.91it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_04027_L.xml:  71%|███████▏  | 259/363 [00:06<00:01, 70.91it/s]Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_12448_L.xml:  71%|███████▏  | 259/363 [00:06<00:01, 70.91it/s]Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_03307_L.xml:  74%|███████▎  | 267/363 [00:06<00:01, 70.39it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_08474_L.xml:  74%|███████▎  | 267/363 [00:06<00:01, 70.39it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/0006_Main_frame.xml:  74%|███████▎  | 267/363 [00:06<00:01, 70.39it/s]  Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_08004_L.xml:  76%|███████▋  | 277/363 [00:06<00:01, 76.72it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_05347_L.xml:  79%|███████▉  | 286/363 [00:07<00:00, 78.90it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_08380_L.xml:  79%|███████▉  | 286/363 [00:07<00:00, 78.90it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_00311_L.xml:  79%|███████▉  | 286/363 [00:07<00:00, 78.90it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_08382_L.xml:  81%|████████  | 294/363 [00:07<00:00, 76.45it/s]Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_08342_L.xml:  81%|████████  | 294/363 [00:07<00:00, 76.45it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_00829_L.xml:  81%|████████  | 294/363 [00:07<00:00, 76.45it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_08537_L.xml:  81%|████████  | 294/363 [00:07<00:00, 76.45it/s]Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_06931_L.xml:  83%|████████▎ | 302/363 [00:07<00:00, 76.05it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_00955_L.xml:  83%|████████▎ | 302/363 [00:07<00:00, 76.05it/s]Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_09102_L.xml:  85%|████████▌ | 310/363 [00:07<00:00, 74.02it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_03847_L.xml:  88%|████████▊ | 320/363 [00:07<00:00, 80.44it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_08472_L.xml:  88%|████████▊ | 320/363 [00:07<00:00, 80.44it/s]Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_05654_L.xml:  88%|████████▊ | 320/363 [00:07<00:00, 80.44it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_01602_L.xml:  88%|████████▊ | 320/363 [00:07<00:00, 80.44it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_02630_L.xml:  88%|████████▊ | 320/363 [00:07<00:00, 80.44it/s]Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_01546_L.xml:  88%|████████▊ | 320/363 [00:07<00:00, 80.44it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_11375_L.xml:  91%|█████████ | 329/363 [00:07<00:00, 79.72it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_05339_L.xml:  91%|█████████ | 329/363 [00:07<00:00, 79.72it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_08002_L.xml:  91%|█████████ | 329/363 [00:07<00:00, 79.72it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_05509_L.xml:  93%|█████████▎| 338/363 [00:07<00:00, 79.07it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_08344_L.xml:  93%|█████████▎| 338/363 [00:07<00:00, 79.07it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_05226_L.xml:  93%|█████████▎| 338/363 [00:07<00:00, 79.07it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_08379_L.xml:  95%|█████████▌| 346/363 [00:07<00:00, 76.40it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_05343_L.xml:  95%|█████████▌| 346/363 [00:07<00:00, 76.40it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_12615_L.xml:  95%|█████████▌| 346/363 [00:07<00:00, 76.40it/s]Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# Warning: invalid UTF8 character encountered (2)!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_05287_L.xml:  95%|█████████▌| 346/363 [00:07<00:00, 76.40it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_01544_L.xml:  98%|█████████▊| 356/363 [00:07<00:00, 79.80it/s]Warning: invalid UTF8 character encountered!
# Warning: invalid UTF8 character encountered!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_06972_L.xml:  98%|█████████▊| 356/363 [00:07<00:00, 79.80it/s]Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# Warning: incomplete utf8 character in function utf8_get_char!
# OMNIA tagger in progress with doc: ./data_filtered/FRAN_0393_12690_L.xml: 100%|██████████| 363/363 [00:08<00:00, 45.35it/s]
# [INFO] *> Initialize nlp_pie_lasla tagger...
# [INFO] *> Directory: ./out_lemmatized_corpus/nlp_pie_lasla is already created.
# NLP_PIE_LASLA tagger in progress with doc: ./data_filtered/FRAN_0393_12690_L.xml: 100%|██████████| 363/363 [06:37<00:00,  1.09s/it]
# [INFO] *> Initialize ud_pipe tagger...
# [INFO] *> Directory: ./out_lemmatized_corpus/ud_pipe_nlp_la_ittb is already created.
# UD_PIPE_NLP_LA_ITTB tagger in progress with doc: ./data_filtered/FRAN_0393_12690_L.xml: 100%|██████████| 363/363 [00:44<00:00,  8.21it/s]
# [INFO] *> Directory: ./out_lemmatized_corpus/ud_pipe_la-proiel is already created.
# UD_PIPE_LA-PROIEL tagger in progress with doc: ./data_filtered/FRAN_0393_12690_L.xml: 100%|██████████| 363/363 [00:51<00:00,  6.99it/s]
# [INFO] *> Directory: ./out_lemmatized_corpus/ud_pipe_la-perseus is already created.
# UD_PIPE_LA-PERSEUS tagger in progress with doc: ./data_filtered/FRAN_0393_12690_L.xml: 100%|██████████| 363/363 [00:35<00:00, 10.29it/s]
# [INFO] *> Benchmark is over ✔️
# CPU times: user 14min 56s, sys: 4min 37s, total: 19min 33s
# Wall time: 13min 45s
